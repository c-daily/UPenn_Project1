# %%
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
csvpath_chi_12 = os.path.join('2009,2019 Weather CSV', 'Chicago 2012.csv')
csvpath_chi_19 = os.path.join('2009,2019 Weather CSV', 'Chicago 2019.csv')
csvpath_LA_12 = os.path.join('2009,2019 Weather CSV', 'LAS 2012.csv')
csvpath_LA_19 = os.path.join('2009,2019 Weather CSV', 'LAS 2019.csv')
csvpath_ny_12 = os.path.join('2009,2019 Weather CSV', 'NY 2012.csv')
csvpath_ny_19 = os.path.join('2009,2019 Weather CSV', 'NY 2019.csv')
csvpath_philly_12 = os.path.join('2009,2019 Weather CSV', 'PHL 2012.csv')
csvpath_philly_19 = os.path.join('2009,2019 Weather CSV', 'PHL 2019.csv')

# %%
# Read CSVs for each city and year into pandas and convert to Data Frame

with open(csvpath_chi_12) as csvfile_chi_12:
    csvreader_chi_12 = csv.reader(csvfile_chi_12, delimiter=",")
    csv_header = next(csvreader_chi_12) 
    chi_12_df_first = pd.DataFrame(csvreader_chi_12)
    
with open(csvpath_chi_19) as csvfile_chi_19:
    csvreader_chi_19 = csv.reader(csvfile_chi_19, delimiter=",")
    csv_header = next(csvreader_chi_19) 
    chi_19_df_first = pd.DataFrame(csvreader_chi_19)

with open(csvpath_LA_12) as csvfile_LA_12:
    csvreader_LA_12 = csv.reader(csvfile_LA_12, delimiter=",")
    csv_header = next(csvreader_LA_12) 
    LA_12_df_first = pd.DataFrame(csvreader_LA_12)

with open(csvpath_LA_19) as csvfile_LA_19:
    csvreader_LA_19 = csv.reader(csvfile_LA_19, delimiter=",")
    csv_header = next(csvreader_LA_19) 
    LA_19_df_first = pd.DataFrame(csvreader_LA_19)

with open(csvpath_ny_12) as csvfile_ny_12:
    csvreader_ny_12 = csv.reader(csvfile_ny_12, delimiter=",")
    csv_header = next(csvreader_ny_12) 
    ny_12_df_first = pd.DataFrame(csvreader_ny_12)

with open(csvpath_ny_19) as csvfile_ny_19:
    csvreader_ny_19 = csv.reader(csvfile_ny_19, delimiter=",")
    csv_header = next(csvreader_ny_19) 
    ny_19_df_first = pd.DataFrame(csvreader_ny_19)
    
with open(csvpath_philly_12) as csvfile_philly_12:
    csvreader_philly_12 = csv.reader(csvfile_philly_12, delimiter=",")
    csv_header = next(csvreader_philly_12) 
    philly_12_df_first = pd.DataFrame(csvreader_philly_12)

with open(csvpath_philly_19) as csvfile_philly_19:
    csvreader_philly_19 = csv.reader(csvfile_philly_19, delimiter=",")
    csv_header = next(csvreader_philly_19) 
    philly_19_df_first = pd.DataFrame(csvreader_philly_19)

# %%
# Renaming original 2012 data frame columns and making a new column to store the Months calculated using a datetimeindex function on Date column 

chi_12_df = chi_12_df_first.rename(columns={0:"Date", 1:"Temp Avg", 2:"Temp Min", 3:"Max Temp",4:"Precipitation", 5:"Snow", 6:"Wind Speed"})
chi_12_df['Day'] = pd.DatetimeIndex(chi_12_df['Date']).day

LA_12_df = LA_12_df_first.rename(columns={0:"Date", 1:"Temp Avg", 2:"Temp Min", 3:"Max Temp",4:"Precipitation", 5:"Snow", 6:"Wind Speed"})
LA_12_df['Day'] = pd.DatetimeIndex(LA_12_df['Date']).day

ny_12_df = ny_12_df_first.rename(columns={0:"Date", 1:"Temp Avg", 2:"Temp Min", 3:"Max Temp",4:"Precipitation", 5:"Snow", 6:"Wind Speed"})
ny_12_df['Day'] = pd.DatetimeIndex(ny_12_df['Date']).day

philly_12_df = philly_12_df_first.rename(columns={0:"Date", 1:"Temp Avg", 2:"Temp Min", 3:"Max Temp",4:"Precipitation", 5:"Snow", 6:"Wind Speed"})
philly_12_df['Day'] = pd.DatetimeIndex(philly_12_df['Date']).day

# %%
# Creating new 2012 Data Frames by grouping on the Month column, converting columns to numeric values, and then finding averages
chi_12_df[["Temp Avg", "Precipitation", "Wind Speed", "Max Temp"]] = chi_12_df[["Temp Avg", "Precipitation", "Wind Speed", "Max Temp"]].apply(pd.to_numeric)
chi_12_day = chi_12_df.groupby(['Day']).mean([['Temp Avg', 'Precipitation', 'Wind Speed']])

LA_12_df[["Temp Avg", "Precipitation", "Wind Speed", "Max Temp"]] = LA_12_df[["Temp Avg", "Precipitation", "Wind Speed", "Max Temp"]].apply(pd.to_numeric)
LA_12_day = LA_12_df.groupby(['Day']).mean([['Temp Avg', 'Precipitation', 'Wind Speed']])

ny_12_df[["Temp Avg", "Precipitation", "Wind Speed", "Max Temp"]] = ny_12_df[["Temp Avg", "Precipitation", "Wind Speed", "Max Temp"]].apply(pd.to_numeric)
ny_12_day = ny_12_df.groupby(['Day']).mean([['Temp Avg', 'Precipitation', 'Wind Speed']])
ny_12_day

philly_12_df[["Temp Avg", "Precipitation", "Wind Speed", "Max Temp"]] = philly_12_df[["Temp Avg", "Precipitation", "Wind Speed", "Max Temp"]].apply(pd.to_numeric)
philly_12_day = philly_12_df.groupby(['Day']).mean([['Temp Avg', 'Precipitation', 'Wind Speed']])
philly_12_day
# Out:
#       Temp Avg   Max Temp  Precipitation  Wind Speed
# Day
# 1    60.935000  69.410000       1.217192    7.922483
# 2    56.765000  64.595000       0.695538    9.217006
# 3    58.775000  67.115000       1.089239    7.715359
# 4    58.790000  66.785000       2.250656    7.352892
# 5    57.755000  66.005000       0.810367    9.009882
# 6    55.445000  65.285000       0.013123    7.456454
# 7    57.170000  66.740000       0.620079    7.715359
# 8    58.805000  67.265000       0.538058    8.958101
# 9    58.130000  66.605000       0.711942    8.388511
# 10   57.080000  65.900000       0.898950    7.663578
# 11   56.300000  66.275000       0.685696    8.233168
# 12   56.780000  66.290000       1.476378    7.974264
# 13   57.935000  68.255000       0.209974    8.854539
# 14   58.010000  66.830000       0.695538    7.404673
# 15   58.250000  66.245000       1.282808    7.249331
# 16   57.995000  67.160000       0.203412    6.058369
# 17   60.155000  69.545000       0.564304    7.404673
# 18   58.355000  68.570000       1.335302    8.906320
# 19   57.920000  66.740000       0.442913    7.301112
# 20   58.205000  67.310000       0.469160    7.352892
# 21   59.150000  68.030000       1.643701    8.284949
# 22   58.805000  67.580000       2.470472    7.767140
# 23   59.030000  69.380000       0.305118    7.301112
# 24   59.480000  67.670000       1.207349    8.802759
# 25   57.290000  64.400000       0.006562    9.268787
# 26   57.560000  66.725000       1.637139    9.475911
# 27   59.375000  67.640000       1.509186    9.890158
# 28   58.670000  67.355000       0.649606    9.009882
# 29   57.110000  65.420000       3.937008   10.200844
# 30   56.692727  64.645455       0.350752    8.247290
# 31   58.074286  65.942857       0.303712    8.255360

# %%
x1 = np.arange(1,32,1)    
y1 = chi_12_day['Max Temp'] 
plt.plot(x1, y1, label = "2012")
plt.xlabel('Month')
plt.ylabel('Fahrenheit')
plt.title('Chicago Max Temp 2012 vs 2019')
plt.legend()
plt.show()

# %%
#Joining crime data for analysis
csvpath_chi_crime_12 = os.path.join('Chicago', 'chicago_crime_2012.csv')
csvpath_chi_crime_19 = os.path.join('Chicago', 'chicago_crime_2019.csv')
csvpath_LA_crime_12 = os.path.join('LA Data', 'la_crime_2012.csv')
csvpath_LA_crime_19 = os.path.join('LA Data', 'la_crime_2019.csv')
csvpath_philly_crime_12 = os.path.join('Philadelphia', 'Philadelphia Crime Data 2012.csv')
csvpath_philly_crime_19 = os.path.join('Philadelphia', 'Philadelphia Crime Data 2019.csv')
csvpath_ny_crime_12 = os.path.join('NYC Data', 'ny_crime_2012.csv')
csvpath_ny_crime_19 = os.path.join('NYC Data', 'ny_crime_2019.csv')

# %%
with open(csvpath_chi_crime_12) as csvfile_chi_crime_12:
    csvreader_chi_crime_12 = csv.reader(csvfile_chi_crime_12, delimiter=",")
    csv_header = next(csvreader_chi_crime_12) 
    chi_crime_12_first = pd.DataFrame(csvreader_chi_crime_12)

# %%
chi_crime_12 = chi_crime_12_first.rename(columns={1:"ID", 2:"Case Number", 3:"Date", 4:"Type", 5:"Description"})

# %%
chi_crime_12['Day'] = pd.DatetimeIndex(chi_crime_12['Date']).day

# %%
chi_crime_day_12 = chi_crime_12.groupby(['Day']).nunique(['ID'])

# %%
x1 = np.arange(1,32,1)    
y1 = chi_crime_day_12['ID']
plt.plot(x1, y1, label = "2012")
plt.ylabel('Number of Crimes Committed')
plt.title('Chicago Crimes 2012 vs 2019')
plt.grid()
plt.legend()
plt.show()

# %%
x_values = chi_12_day['Max Temp']
y_values = chi_crime_day_12['ID']

correlation_matrix = np.corrcoef(x_values, y_values)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2

# %%
r_squared
# Out:
# 0.09502641036100155
